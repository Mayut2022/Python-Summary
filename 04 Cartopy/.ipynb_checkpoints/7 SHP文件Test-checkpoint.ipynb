# %% [markdown]
# 1. shp_path1 = r'E:\SHP\gadm36_CHN_shp\gadm36_CHN_0.shp' 只有中国大陆，没有台湾及南海
# 2. 十大流域不知道为什么显示不了
# 3. shp_path5 = r'E:\SHP\Provincial boundary_bou2_4m\bou2_4l.shp' 完整的中国省界加台湾和南海
# 4. 同3的4p，没有九段线

# %%
import cmaps
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
from cartopy.io.shapereader import Reader, natural_earth
import matplotlib.pyplot as plt
from matplotlib.path import Path
from matplotlib.patches import PathPatch
import xarray as xr
import numpy as np
from natsort import os_sorted
import os
import shapefile

# %%
fig = plt.figure(figsize=(10, 6), dpi=1080)
proj = ccrs.PlateCarree()
ax = fig.add_subplot(111, projection=proj)
# ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.8)
# ax.add_feature(cfeature.RIVERS.with_scale('50m'), linewidth=0.8, zorder=2)

# 设置shp文件
shp_path1 = r'E:\SHP\gadm36_CHN_shp\gadm36_CHN_0.shp'
# shp_path2 = r'E:/SHP/world_shp/world_adm0_Project.shp'
shp_path3 = r'E:\SHP\cnmap\cnmap.shp'
shp_path4 = r'E:\SHP\01_十大流域\长江流域\长江流域.shp'
shp_path5 = r'E:\SHP\Provincial boundary_bou2_4m\bou2_4l.shp'

provinces = cfeature.ShapelyFeature(
    Reader(shp_path1).geometries(),
    ccrs.PlateCarree(),
    edgecolor='k',
    facecolor='none')

# world = cfeature.ShapelyFeature(
#     Reader(shp_path2).geometries(),
#     ccrs.PlateCarree(),
#     edgecolor='k',
#     facecolor='none')

yellow = cfeature.ShapelyFeature(
    Reader(shp_path3).geometries(),
    ccrs.PlateCarree(),
    edgecolor='b',
    facecolor='none')

cj = cfeature.ShapelyFeature(
    Reader(shp_path4).geometries(),
    ccrs.PlateCarree(),
    edgecolor='b',
    facecolor='k')

chn = cfeature.ShapelyFeature(
    Reader(shp_path5).geometries(),
    ccrs.PlateCarree(),
    edgecolor='b',
    facecolor='none')

# ax.add_feature(provinces, linewidth=1, zorder=3)
# ax.add_feature(world, linewidth=0.8, zorder=3)
ax.add_feature(yellow, linewidth=1, zorder=3)
# ax.add_feature(cj, linewidth=1, zorder=3)
# ax.add_feature(chn, linewidth=1, zorder=3)

# 区域
region = [70, 140, 15, 55]
ax.set_extent(region, crs=ccrs.PlateCarree())

## 添加南海
sub_ax = fig.add_axes([0.8, 0.2, 0.1, 0.2], projection=proj)
sub_ax.set_extent([105, 125, 0, 26])
sub_ax.add_feature(chn, linewidth=1, zorder=3)
# sub_ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.8)
