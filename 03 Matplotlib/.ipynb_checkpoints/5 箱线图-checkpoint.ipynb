# %% [markdown]
# > 箱线图结构组成：箱体box、异常值filer、中位数median、均值mean、顶端和末端cap、须whisker
#
# > 异常值及极端异常值 1.5*(Q3-Q2) 3*(Q3-Q2)

# %% [markdown]
# # Matplotlib
# > [官网](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.boxplot.html#matplotlib.axes.Axes.boxplot)
# > [Python Matplotlib数据可视化绘图之（二）————箱线图](https://blog.csdn.net/Mr_Dragon66/article/details/127814202?ops_request_misc=&request_id=&biz_id=102&utm_term=python%20%E5%88%86%E7%BB%84%E7%AE%B1%E7%BA%BF%E5%9B%BE&utm_medium=distribute.pc_search_result.none-task-blog-2~all~sobaiduweb~default-5-127814202.142^v86^insert_down38v5,239^v2^insert_chatgpt&spm=1018.2226.3001.4187)
# ![image.png](attachment:image.png)

# %% [markdown]
# # Pandas 分组箱线图
# > [在一幅图中为箱线图设置不同颜色](https://blog.csdn.net/liuchengzimozigreat/article/details/85037838)
# [python-matplotlib-箱线图为不同的箱体设置不同颜色](https://blog.csdn.net/qq_37006625/article/details/127908633)

# %% [markdown]
# # Seaborn
# > [官网](http://seaborn.pydata.org/generated/seaborn.boxplot.html#seaborn.boxplot)
#
# > 存在问题：
# > 1. 分组箱线图详细设置须结合mpl，如何对每组数据进行单独设置？
